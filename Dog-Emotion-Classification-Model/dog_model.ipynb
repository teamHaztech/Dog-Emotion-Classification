# %%
# %pip install numpy librosa scikit-learn

# Optional for saving and loading models
# %pip install pickle-mixin

# %pip install imblearn
# Out:
# Requirement already satisfied: numpy in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (2.0.2)
# Requirement already satisfied: librosa in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (0.10.2.post1)
# Requirement already satisfied: scikit-learn in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (1.5.2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from librosa) (1.14.1)
# Requirement already satisfied: joblib>=0.14 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: packaging in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from lazy-loader>=0.1->librosa) (24.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: cffi>=1.0 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pickle-mixin in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (1.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: imblearn in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from imblearn) (0.12.4)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from imbalanced-learn->imblearn) (2.0.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from imbalanced-learn->imblearn) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asfor\onedrive\desktop\backend-rebder - copy\.venv\lib\site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
            # import os
            # import numpy as np
            # import librosa
            # from sklearn.ensemble import RandomForestClassifier
            # from sklearn.model_selection import train_test_split, RandomizedSearchCV
            # from sklearn.metrics import classification_report
            # from sklearn.feature_selection import RFE
            # import pickle
            # from sklearn.model_selection import cross_val_score

            # # Ensure model directory exists
            # model_dir = 'model'
            # os.makedirs(model_dir, exist_ok=True)

            # # 1. Function to extract features from audio files
            # def extract_features(y, sr):
            #     mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=10)  # Change to 10 MFCCs
            #     chroma = librosa.feature.chroma_stft(y=y, sr=sr)
            #     spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
                
            #     return np.concatenate((
            #         np.mean(mfccs.T, axis=0), 
            #         np.mean(chroma.T, axis=0),
            #         np.mean(spectral_contrast.T, axis=0)
            #     ))

            # # 2. Data Augmentation function for increasing dataset size
            # def augment_audio(y, sr):
            #     y_shifted = librosa.effects.pitch_shift(y, sr=sr, n_steps=2)
            #     y_stretched = librosa.effects.time_stretch(y, rate=0.8)
            #     noise = np.random.randn(len(y))
            #     y_noisy = y + 0.005 * noise
                
            #     return [y_shifted, y_stretched, y_noisy]

            # # 3. Load dataset and apply feature extraction and augmentation
            # def load_dataset(dataset_path):
            #     features = []
            #     labels = []
                
            #     for category in os.listdir(dataset_path):
            #         category_path = os.path.join(dataset_path, category)
                    
            #         for file_name in os.listdir(category_path):
            #             file_path = os.path.join(category_path, file_name)
            #             y, sr = librosa.load(file_path, sr=22050)
            #             feature = extract_features(y, sr)
            #             features.append(feature)
            #             labels.append(category)
                        
            #             for augmented in augment_audio(y, sr):
            #                 augmented_feature = extract_features(augmented, sr)
            #                 features.append(augmented_feature)
            #                 labels.append(category)
                
            #     return np.array(features), np.array(labels)

            # # 4. Load the dataset
            # dataset_path = 'processed_dataset'
            # features, labels = load_dataset(dataset_path)

            # # 5. Split data into train and test sets
            # X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

            # # 6. Check class distribution
            # unique, counts = np.unique(labels, return_counts=True)
            # class_distribution = dict(zip(unique, counts))
            # print("Class distribution:", class_distribution)

            # # 7. Hyperparameter tuning using RandomizedSearchCV
            # param_grid = {
            #     'n_estimators': [100, 200],
            #     'max_depth': [10, None],
            #     'min_samples_split': [2, 5],
            #     'min_samples_leaf': [1, 2],
            #     'bootstrap': [True]
            # }

            # clf = RandomForestClassifier(random_state=42)
            # random_search = RandomizedSearchCV(estimator=clf, param_distributions=param_grid, 
            #                                 n_iter=10, cv=5, verbose=2, n_jobs=2, random_state=42)
            # random_search.fit(X_train, y_train)

            # # Get the best parameters
            # best_params = random_search.best_params_
            # print("Best parameters found: ", best_params)

            # # 8. Train the model with the best parameters
            # best_clf = random_search.best_estimator_
            # best_clf.fit(X_train, y_train)

            # # 9. Perform feature selection using Recursive Feature Elimination (RFE)
            # rfe = RFE(estimator=best_clf, n_features_to_select=10, step=1)
            # rfe.fit(X_train, y_train)

            # # Transform the data based on the selected features
            # X_train_rfe = rfe.transform(X_train)
            # X_test_rfe = rfe.transform(X_test)

            # print(f"Number of features after RFE: {X_train_rfe.shape[1]}")

            # # Re-train model with selected features
            # best_clf.fit(X_train_rfe, y_train)

            # # 10. Evaluate the model
            # y_pred = best_clf.predict(X_test_rfe)
            # print(classification_report(y_test, y_pred))

            # # 11. Cross-validate the model for better performance estimation
            # cv_scores = cross_val_score(best_clf, X_train_rfe, y_train, cv=5)
            # print(f"Cross-validated accuracy: {np.mean(cv_scores):.4f}")

            # # 12. Save the trained model and RFE selector in the 'model' folder
            # model_path = os.path.join(model_dir, 'dog_bark_classifier33.pkl')
            # rfe_path = os.path.join(model_dir, 'rfe_selector.pkl')

            # with open(model_path, 'wb') as model_file:
            #     pickle.dump(best_clf, model_file)

            # with open(rfe_path, 'wb') as rfe_file:
            #     pickle.dump(rfe, rfe_file)

            # # 13. Load the trained model and RFE selector for future use
            # with open(model_path, 'rb') as model_file:
            #     loaded_model = pickle.load(model_file)

            # with open(rfe_path, 'rb') as rfe_file:
            #     rfe = pickle.load(rfe_file)

            # # Function to handle file prediction
            # def handle_file_prediction(file_path):
            #     y, sr = librosa.load(file_path, sr=22050)
            #     features = extract_features(y, sr)
                
            #     features_rfe = rfe.transform(features.reshape(1, -1))  # Reshape for single sample
            #     prediction = loaded_model.predict(features_rfe)
            #     return prediction


# import os
# import numpy as np
# import librosa
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split, RandomizedSearchCV
# from sklearn.metrics import classification_report
# from sklearn.feature_selection import RFE
# import pickle
# from sklearn.model_selection import cross_val_score

# # Ensure model directory exists
# model_dir = 'model'
# os.makedirs(model_dir, exist_ok=True)

# # 1. Function to extract features from audio files
# def extract_features(y, sr):
#     mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=10)  # Change to 10 MFCCs
#     chroma = librosa.feature.chroma_stft(y=y, sr=sr)
#     spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
    
#     return np.concatenate((
#         np.mean(mfccs.T, axis=0), 
#         np.mean(chroma.T, axis=0),
#         np.mean(spectral_contrast.T, axis=0)
#     ))

# # 2. Data Augmentation function for increasing dataset size
# def augment_audio(y, sr):
#     y_shifted = librosa.effects.pitch_shift(y, sr=sr, n_steps=2)
#     y_stretched = librosa.effects.time_stretch(y, rate=0.8)
#     noise = np.random.randn(len(y))
#     y_noisy = y + 0.005 * noise
    
#     return [y_shifted, y_stretched, y_noisy]

# # 3. Load dataset and apply feature extraction and augmentation
# def load_dataset(dataset_path):
#                 features = []
#                 labels = []
                
#                 for category in os.listdir(dataset_path):
#                     category_path = os.path.join(dataset_path, category)
                    
#                     for file_name in os.listdir(category_path):
#                         file_path = os.path.join(category_path, file_name)
#                         y, sr = librosa.load(file_path, sr=22050)
#                         feature = extract_features(y, sr)
#                         features.append(feature)
#                         labels.append(category)
                        
#                         for augmented in augment_audio(y, sr):
#                             augmented_feature = extract_features(augmented, sr)
#                             features.append(augmented_feature)
#                             labels.append(category)
                
#                 return np.array(features), np.array(labels)            


# # 4. Load the dataset
# dataset_path = 'processed_dataset'
# features, labels = load_dataset(dataset_path)

# # 5. Split data into train and test sets
# X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# # 6. Check class distribution
# unique, counts = np.unique(labels, return_counts=True)
# class_distribution = dict(zip(unique, counts))
# print("Class distribution:", class_distribution)

# # 7. Hyperparameter tuning using RandomizedSearchCV
# param_grid = {
#     'n_estimators': [100, 200],
#     'max_depth': [10, None],
#     'min_samples_split': [2, 5],
#     'min_samples_leaf': [1, 2],
#     'bootstrap': [True]
# }

# clf = RandomForestClassifier(random_state=42)
# random_search = RandomizedSearchCV(estimator=clf, param_distributions=param_grid, 
#                                    n_iter=10, cv=5, verbose=2, n_jobs=2, random_state=42)
# random_search.fit(X_train, y_train)

# # Get the best parameters
# best_params = random_search.best_params_
# print("Best parameters found: ", best_params)

# # 8. Train the model with the best parameters
# best_clf = random_search.best_estimator_
# best_clf.fit(X_train, y_train)

# # 9. Perform feature selection using Recursive Feature Elimination (RFE)
# rfe = RFE(estimator=best_clf, n_features_to_select=10, step=1)
# rfe.fit(X_train, y_train)

# # Transform the data based on the selected features
# X_train_rfe = rfe.transform(X_train)
# X_test_rfe = rfe.transform(X_test)

# print(f"Number of features after RFE: {X_train_rfe.shape[1]}")

# # Re-train model with selected features
# best_clf.fit(X_train_rfe, y_train)

# # 10. Evaluate the model
# y_pred = best_clf.predict(X_test_rfe)
# print(classification_report(y_test, y_pred))

# # 11. Cross-validate the model for better performance estimation
# cv_scores = cross_val_score(best_clf, X_train_rfe, y_train, cv=5)
# print(f"Cross-validated accuracy: {np.mean(cv_scores):.4f}")

# # 12. Save the trained model and RFE selector in the 'model' folder
# model_path = os.path.join(model_dir, 'dog_bark_classifier.pkl')
# rfe_path = os.path.join(model_dir, 'rfe_selector.pkl')

# with open(model_path, 'wb') as model_file:
#     pickle.dump(best_clf, model_file)

# with open(rfe_path, 'wb') as rfe_file:
#     pickle.dump(rfe, rfe_file)

# # 13. Load the trained model and RFE selector for future use
# with open(model_path, 'rb') as model_file:
#     loaded_model = pickle.load(model_file)

# with open(rfe_path, 'rb') as rfe_file:
#     rfe = pickle.load(rfe_file)

# # Function to handle file prediction
# def handle_file_prediction(file_path):
#     y, sr = librosa.load(file_path, sr=22050)
#     features = extract_features(y, sr)
    
#     features_rfe = rfe.transform(features.reshape(1, -1))  # Reshape for single sample
#     prediction = loaded_model.predict(features_rfe)
#     return prediction

# %%
import os
import numpy as np
import librosa
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import classification_report, accuracy_score, precision_recall_fscore_support
from sklearn.feature_selection import RFE
import pickle
from sklearn.model_selection import cross_val_score

# Ensure model directory exists
model_dir = 'model'
os.makedirs(model_dir, exist_ok=True)

# 1. Function to extract features from audio files
def extract_features(y, sr):
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=10)  # Change to 10 MFCCs
    chroma = librosa.feature.chroma_stft(y=y, sr=sr)
    spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
    
    return np.concatenate(( 
        np.mean(mfccs.T, axis=0), 
        np.mean(chroma.T, axis=0),
        np.mean(spectral_contrast.T, axis=0)
    ))

# 2. Data Augmentation function for increasing dataset size
def augment_audio(y, sr):
    y_shifted = librosa.effects.pitch_shift(y, sr=sr, n_steps=2)
    y_stretched = librosa.effects.time_stretch(y, rate=0.8)
    noise = np.random.randn(len(y))
    y_noisy = y + 0.005 * noise
    
    return [y_shifted, y_stretched, y_noisy]

# 3. Load dataset and apply feature extraction and augmentation
def load_dataset(dataset_path):
    features = []
    labels = []
                
    for category in os.listdir(dataset_path):
        category_path = os.path.join(dataset_path, category)
                    
        for file_name in os.listdir(category_path):
            file_path = os.path.join(category_path, file_name)
            y, sr = librosa.load(file_path, sr=22050)
            feature = extract_features(y, sr)
            features.append(feature)
            labels.append(category)
                        
            for augmented in augment_audio(y, sr):
                augmented_feature = extract_features(augmented, sr)
                features.append(augmented_feature)
                labels.append(category)
                
    return np.array(features), np.array(labels)

# 4. Load the dataset
dataset_path = 'processed_dataset'
features, labels = load_dataset(dataset_path)

# 5. Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# 6. Check class distribution
unique, counts = np.unique(labels, return_counts=True)
class_distribution = dict(zip(unique, counts))
print("Class distribution:", class_distribution)

# 7. Hyperparameter tuning using RandomizedSearchCV
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True]
}

clf = RandomForestClassifier(random_state=42)
random_search = RandomizedSearchCV(estimator=clf, param_distributions=param_grid, 
                                   n_iter=10, cv=5, verbose=2, n_jobs=2, random_state=42)
random_search.fit(X_train, y_train)

# Get the best parameters
best_params = random_search.best_params_
print("Best parameters found: ", best_params)

# 8. Train the model with the best parameters
best_clf = random_search.best_estimator_
best_clf.fit(X_train, y_train)

# 9. Perform feature selection using Recursive Feature Elimination (RFE)
rfe = RFE(estimator=best_clf, n_features_to_select=10, step=1)
rfe.fit(X_train, y_train)

# Transform the data based on the selected features
X_train_rfe = rfe.transform(X_train)
X_test_rfe = rfe.transform(X_test)

print(f"Number of features after RFE: {X_train_rfe.shape[1]}")

# Re-train model with selected features
best_clf.fit(X_train_rfe, y_train)

# 10. Evaluate the model
y_pred = best_clf.predict(X_test_rfe)
print(classification_report(y_test, y_pred))

# Calculate accuracy, precision, recall, and F1-score
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='weighted')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# 11. Cross-validate the model for better performance estimation
cv_scores = cross_val_score(best_clf, X_train_rfe, y_train, cv=5)
print(f"Cross-validated accuracy: {np.mean(cv_scores):.4f}")

# Save performance metrics
performance_metrics = {
    'accuracy': accuracy,
    'precision': precision,
    'recall': recall,
    'f1_score': f1,
    'cross_val_accuracy': np.mean(cv_scores)
}

# 12. Save the trained model, RFE selector, and performance metrics in the 'model' folder
model_path = os.path.join(model_dir, 'dog_bark_classifier.pkl')
rfe_path = os.path.join(model_dir, 'rfe_selector.pkl')
metrics_path = os.path.join(model_dir, 'performance_metrics.pkl')

with open(model_path, 'wb') as model_file:
    pickle.dump(best_clf, model_file)

with open(rfe_path, 'wb') as rfe_file:
    pickle.dump(rfe, rfe_file)

with open(metrics_path, 'wb') as metrics_file:
    pickle.dump(performance_metrics, metrics_file)

# 13. Load the trained model, RFE selector, and performance metrics for future use
with open(model_path, 'rb') as model_file:
    loaded_model = pickle.load(model_file)

with open(rfe_path, 'rb') as rfe_file:
    rfe = pickle.load(rfe_file)

with open(metrics_path, 'rb') as metrics_file:
    performance_metrics = pickle.load(metrics_file)

# Optionally, print the metrics to verify
print(f"Loaded performance metrics: {performance_metrics}")
# Out:
# Class distribution: {np.str_('Unknown'): np.int64(88), np.str_('aggressive'): np.int64(120), np.str_('happy'): np.int64(8), np.str_('howling'): np.int64(32), np.str_('pain'): np.int64(88)}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best parameters found:  {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True}
# Number of features after RFE: 10
# c:\Users\asfor\OneDrive\Desktop\Backend-rebder - Copy\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\asfor\OneDrive\Desktop\Backend-rebder - Copy\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\asfor\OneDrive\Desktop\Backend-rebder - Copy\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\asfor\OneDrive\Desktop\Backend-rebder - Copy\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#      Unknown       1.00      0.95      0.97        19
#   aggressive       0.88      0.97      0.92        29
#        happy       0.00      0.00      0.00         0
#      howling       1.00      1.00      1.00         7
#         pain       0.90      0.69      0.78        13
#
#     accuracy                           0.91        68
#    macro avg       0.76      0.72      0.73        68
# weighted avg       0.93      0.91      0.92        68
#
# Accuracy: 0.9118
# Precision: 0.9276
# Recall: 0.9118
# F1 Score: 0.9159
# Cross-validated accuracy: 0.9104
# Loaded performance metrics: {'accuracy': 0.9117647058823529, 'precision': np.float64(0.9275735294117647), 'recall': np.float64(0.9117647058823529), 'f1_score': np.float64(0.9159316227887776), 'cross_val_accuracy': np.float64(0.9104122990915444)}
